# %% [markdown]
# # MidTerm 1 - ML; KBTU

# %% [markdown]
# ### О задании
#
# __Первая часть__ задания посвящена получению студентами навыков работы с библиотекой векторного вычисления numpy и библиотеками для построения графиков matplotlib/plotly.
#
# __Вторая часть__ задания посвящена работе с данными: их преобразованию в нужный формат и устранению проблем в них.
#
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце Вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке.
#
#
# ### Формат сдачи
# Для сдачи задания переименуйте получившийся файл *.ipynb в соответствии со следующим форматом: Midterm-Username.ipynb, где Username — Ваша фамилия и имя на латинице именно в таком порядке. Приложите модули с кодом functions.py и functions_vectorized.py и заархивируйте в zip формат. Имя архива должно быть homework-practice-01-Username.zip
#
# Далее отправьте этот файл на aa.pak83@gmail.com.
#
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.

# %% [markdown]
# **Оценка:** ...

# %% [markdown]
# ## Часть 1
#
# _Задачи позаимствованы из курса практикума кафедры ММП факультета ВМК МГУ_

# %% [markdown]
# ### Задачи 1-6
# __(4.5 балла)__
#
# Ниже приведены задачи на работу с numpy-массивами. Для каждой из задач нужно привести 2 реализации: одна без использования numpy (cчитайте, что там, где на входе или выходе должны быть numpy array, будут просто списки), а вторая полностью векторизованная (без использования питоновских циклов/map/list comprehension). Невекторизованная реализация каждой из задач оценивается в __0.25 балла__, векторизованная – в __0.5 балла__.
#
# Для удобства проверки приложите в ячейке ниже ссылки на самые успешные посылки.
#
#
# * __Задача 1__: Подсчитать произведение ненулевых элементов на диагонали прямоугольной матрицы.
#  Например, для X = np.array([[1, 0, 1], [2, 0, 2], [3, 0, 3], [4, 4, 4]]) ответ – 3.
#
#
# * __Задача 2__: Даны два вектора x и y. Проверить, задают ли они одно и то же мультимножество.
#   Например, для x = np.array([1, 2, 2, 4]), y = np.array([4, 2, 1, 2]) ответ – True.
#
#
# * __Задача 3__: Найти максимальный элемент в векторе x среди элементов, перед которыми стоит нулевой.
#  Например, для x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0]) ответ – 5.
#
#
# * __ Задача 4__: Дан трёхмерный массив, содержащий изображение, размера (height, width, numChannels), а также вектор длины numChannels. Сложить каналы изображения с указанными весами, и вернуть результат в виде матрицы размера (height, width). В ноутбуке приведите пример работы функции – преобразуйте цветное изображение в оттенки серого, использовав коэффициенты np.array([0.299, 0.587, 0.114]). Считать реальное изображение можно при помощи функции scipy.misc.imread (если изображение не в формате png, установите пакет pillow).
#
#
# * __Задача 5__: Реализовать кодирование длин серий (Run-length encoding). Для некоторого вектора x необходимо вернуть кортеж из двух векторов одинаковой длины. Первый содержит числа, а второй - сколько раз их нужно повторить.
#  Например, для x = np.array([2, 2, 2, 3, 3, 3, 5]) ответ – (np.array([2, 3, 5]), np.array([3, 3, 1])).
#
#
# * __Задача 6__: Даны две выборки объектов - X и Y. Вычислить матрицу евклидовых расстояний между объектами. Сравните с функцией scipy.spatial.distance.cdist по скорости работы (сравнения приведите ниже в ноутбуке).
#
# __Замечание.__ Можно считать, что все указанные объекты непустые (к примеру, в __задаче 1__ на диагонали матрицы есть ненулевые элементы) и корректные.

# %%
import numpy as np

# %%
#Zadacha 1, with Numpy
x = np.array([[1, 0, 1], [2, 0, 2], [3, 0, 3], [4, 4, 4]])
x = x.diagonal()
x = np.setdiff1d(x, np.array([0]))
print x.prod()
# Out:
# 3

# %%
#Zadacha 1, without Numpy
x = list([[1, 0, 1], [2, 0, 2], [3, 0, 3], [4, 4, 4]])
n = len(x[0])
y = 1
for i in range(n):
    if x[i][i] != 0:
        y = y * x[i][i]
print y
# Out:
# 3

# %%
#Zadacha 2, withNumpy
x = np.array([1, 2, 2, 4])
y = np.array([4, 2, 1, 2])
x.sort()
y.sort()
np.array_equal(x, y)
# Out:
# True

# %%
#Zadacha 2, wihtoutNumpy
x = list([1, 2, 2, 4])
y = list([4, 2, 1, 2])
a = [0] * 1000000
for i in x:
    a[i] = a[i] + 1
for i in y:
    a[i] = a[i] - 1
b = 0
for i in range(1000000):
    if a[i] != 0:
        b = 1
        break
if b == 0:
    print 'True'
else:
    print 'False'
# Out:
# True

# %% [markdown]
# Посылка по невекторизованным функциям: ...
#
# Посылка по векторизованным функциям: ...

# %%
#Zadacha 3, withNumpy
x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0]) 
zero = x==0
print x[1:][zero[:-1]].max()
# Out:
# 5

# %%
#Zadacha 3, wihtoutNumpy
x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0]) 
last = 0
ans = 0
for i in x:
    if i == 0:
        last = 1
    else:
        if last == 1:
            ans = max (i, ans)
        last = 0
print ans
# Out:
# 5

# %%
#Zadacha 5, withNumpy
x = np.array([2, 2, 2, 3, 3, 3, 5]) 
unique, counts = np.unique(x, return_counts=True)
print unique, counts
# Out:
# [2 3 5]
# [3 3 1]

# %%
#Zadacha 5, withoutNumpy
x = list([2, 2, 2, 3, 3, 3, 5])
x.sort()
m = {}
for i in x:
    if m.get(i):
        m[i] = m[i] + 1
    else:
        m[i] = 1
unique = []
counts = []
for key in m:
    unique.append(key)
    counts.append(m[key])
print unique, counts
# Out:
# [2, 3, 5] [3, 3, 1]

# %%
#Zadacha 6, withNumpy
from scipy.spatial import distance_matrix
distance_matrix([[1],[2],[3],[4]],[[5],[6],[7],[8]])
# Out:
# array([[4., 5., 6., 7.],
#        [3., 4., 5., 6.],
#        [2., 3., 4., 5.],
#        [1., 2., 3., 4.]])

# %%
#Zadacha 6, wihtoutNumpy
import math
import time,sys
x = [1, 2, 3, 4]
y = [1, 2, 3, 4]
ans = []
for i in range(len(x)):
    a = []
    for j in range(len(x)):
        a.append(math.sqrt((x[i] - y[j])*(x[i] - y[j])))
    ans.append(newar)
print ans
# Out:
# [[3.0, 2.0, 1.0, 0.0], [3.0, 2.0, 1.0, 0.0], [3.0, 2.0, 1.0, 0.0], [3.0, 2.0, 1.0, 0.0]]

# %%
#Zadacha 4
from PIL import Image 
image_file = Image.open("hello.png") 
image_file = image_file.convert('1') 
image_file
# Out:
# <PIL.Image.Image image mode=1 size=4919x2156 at 0x111EA6C10>

# %%
#Zadacha 4
import pylab as pl
import matplotlib.cm as cm
import numpy as np
basewidth = 300
img = Image.open('hello.png')
wpercent = (basewidth/float(img.size[0]))
hsize = int((float(img.size[1])*float(wpercent)))
img = img.resize((basewidth,hsize), Image.ANTIALIAS)
image = img
image_grey = image.convert('L') 
image_array = np.array(image_grey)
pl.imshow(image_array, cmap=cm.Greys_r)
pl.show()

# %% [markdown]
# ### Задача 7
# __(1.5 балла)__
# Для каждой задачи сравните скорость работы невекторизованной и векторизованной реализации. С помощью пакета matplotlib или plotly постройте графики времени работы в зависимости от размера данных. __Графики должны выглядеть опрятно!__ То есть должны быть подписаны оси, названия графиков, и т.д. Например, ниже представлены хороший и плохой графики:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

data_size = np.array([10, 30, 70, 120])
time_non_vectorized = data_size ** 2 + 10
time_vectorized = data_size ** 1.5

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))

ax1.plot(data_size, time_non_vectorized)
ax1.plot(data_size, time_vectorized)
ax1.set_title(u"Плохой график")
ax1.set_xlabel(u"Размер данных")
ax1.set_ylabel(u"Время")

ax2.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
ax2.plot(data_size, time_vectorized, label=u"Векторизованная")
ax2.set_title(u"Хороший график")
ax2.set_xlabel(u"Длина массива")
ax2.set_ylabel(u"Время (с)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/figure.py:402: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
# Your code here
# ...

# %% [markdown]
# ## Часть 2
#
# В данном задании мы рассмотрим набор данных об учащихся, собранный в 2006 году в одной из школ Португалии. Данные представлены в неудобном для машинного обучения виде, и содержат мусор. Ваша задача &mdash; привести их к надлежащему виду и обучить на них простую модель.
#
# **Внимание!** Хотя исходные данные для этого задания можно найти в интернете, делать это запрещается. Вся необходимая информация о данных содержится в задании.
#
# Данные состоят из четырех файлов:
# - data.csv &mdash; основная таблица с информацией о учащихся
# - scores.csv &mdash; список финальных оценок по одному из предметов (20-балльная шкала переведенная в проценты)
# - attendance.csv &mdash; таблица посещений занятий по этому предмету
# - school_support.txt &mdash; список учащихся, которым оказывается финансовая поддержка
#
# Ваша задача &mdash; построить модель для предсказания финальных оценок исходя из всех остальных данных. В качестве алгоритма мы будем использовать линейную регрессию, ак ачество будем измерять по метрике RMSE.
#
# Расшифровка столбцов в data.csv для справки:
# - age &mdash; возраст
# - Medu &mdash; уровень образования матери (по некоторой условной шкале)
# - Fedu &mdash; уровень образования отца (по некоторой условной шкале)
# - traveltime &mdash; время в пути до школы (1 – < 15 мин., 2 – от 15 до 30 мин., 3 – от 30 мин. to 1 ч.
# или 4 – > 1 ч.)
# - studytime &mdash; время, затрачиваемое на занятия вне школы (1 – < 2 ч., 2 – от 2 до 5 ч., 3 – от 5 до 10 ч. или 4 – > 10 ч.)
# - famrel &mdash; насколько хорошие отношения в семье у учащегося (по некоторой условной шкале)
# - freetime &mdash; количество свободного времени вне школы (по некоторой условной шкале)
# - goout &mdash; время, затрачиваемое на общение с друзьями (по некоторой условной шкале)
# - Dalc &mdash; количество употребления алкоголя в учебные дни (по некоторой условной шкале)
# - Walc &mdash; количество употребления алкоголя в неучебные дни (по некоторой условной шкале)
# - health &mdash; уровень здоровья (по некоторой условной шкале)
# - sex_M &mdash; пол: мужской (1) или женский (0)
# - address_U &mdash; живет ли учащийся в городе (1) или в пригороде (0)
# - famsize_LE3 &mdash; размер семьи: не больше 3 человек (1) или больше (0)
# - Pstatus_T &mdash; живут ли родители вместе (1) или отдельно (0)
# - nursery &mdash; посещал ли учащийся детский сад
# - plans_university &mdash; планирует ли учащийся поступать в университет (-1 или 1)
# - past_failures &mdash; количество неудовлетворительных оценок по другим предметам ранее (от 0 до 4)

# %% [markdown]
# ### Задача 1: пропуски в данных
# __(0.5 балла)__
#
# Загрузите таблицу data.csv. Проверьте, есть ли в ней пропуски (значения NaN). Замените все пропущенные значения на среднее значение этого признака по столбцу.
#
# *Hint: изучите в pandas функции loc, isnull, а также передачу булевых массивов в качестве индексов.*

# %%
# Your code here
# ...
import pandas as pd
import numpy as np
data = pd.read_csv("data.csv")
pd.isnull(data)
print data.isnull().sum()
data = data.fillna(data.mean())
print data.isnull().sum()
# Out:
# age                               0
# Medu                              0
# Fedu                              0
# traveltime                        0
# studytime                         0
# famrel                            0
# freetime                          0
# goout                             1
# Dalc                             10
# Walc                              6
# health                            0
# sex_M                             0
# address_U                         0
# famsize_LE3                       0
# Pstatus_T                         0
# nursery                           0
# plans_universitypast_failures     0
# dtype: int64
# age                              0
# Medu                             0
# Fedu                             0
# traveltime                       0
# studytime                        0
# famrel                           0
# freetime                         0
# goout                            0
# Dalc                             0
# Walc                             0
# health                           0
# sex_M                            0
# address_U                        0
# famsize_LE3                      0
# Pstatus_T                        0
# nursery                          0
# plans_universitypast_failures    0
# dtype: int64

# %% [markdown]
# ### Задача 2: кросс-валидация для исходных данных
# __(0.5 балла)__
#
# Загрузите файл scores.csv и протестируйте, как линейная регрессия предсказывает ответ сейчас (с помощью кросс-валидации).
#
# *Hint: воспользуйтесь sklearn.linear_model и sklearn.model_selection.*

# %%
# Your code here
# ...
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

target = pd.read_csv("scores.csv")

# %%
target.shape
# Out:
# (649, 1)

# %%
model = LinearRegression()
cross_val_score(model, data, target).mean()
# Out:
# 0.14102754109995305

# %% [markdown]
# ### Задача 3: полные данные
# __(1 балл)__
#
# Воспользуйтесь файлами attendance.csv и school_support.txt для того, чтобы добавить новые признаки в данные. Желательно по максимуму использовать возможности pandas для упрощения преобразований.

# %%
attendance = pd.read_csv("attendance.csv", sep=';')
school = pd.read_csv("school_support.txt")

# %%
def f(x):
    return (x == '+').sum()

att = pd.Series(name="attedance", data = [f(attendance.iloc[i]) for i in range(649)])

# %%
data["attedance"] = att

# %%
# Out:
#      age  Medu  Fedu  traveltime  studytime  famrel  freetime  goout  \
# 0     16     4     4           1          2       5         4    4.0
# 1     17     4     4           1          1       5         3    4.0
# 2     16     1     1           2          1       4         5    5.0
# 3     18     1     2           2          1       3         4    4.0
# 4     17     2     1           2          2       4         2    5.0
# 5     17     2     4           1          2       4         3    2.0
# 6     15     1     1           3          2       4         2    1.0
# 7     15     3     3           1          4       4         3    3.0
# 8     19     1     1           3          1       4         4    4.0
# 9     17     1     1           1          3       4         3    2.0
# 10    16     3     3           1          2       4         3    3.0
# 11    15     2     2           3          1       4         3    3.0
# 12    17     4     4           1          2       2         3    4.0
# 13    16     3     3           2          1       4         3    2.0
# 14    17     3     3           1          1       4         3    5.0
# 15    19     4     3           1          2       4         3    1.0
# 16    16     1     0           2          2       4         3    2.0
# 17    18     2     4           1          2       2         3    2.0
# 18    16     2     1           1          2       5         3    3.0
# 19    18     2     2           2          3       4         2    1.0
# 20    16     4     4           1          2       4         5    2.0
# 21    19     3     3           1          4       4         3    3.0
# 22    18     1     2           2          1       4         1    4.0
# 23    19     1     1           3          3       1         5    5.0
# 24    18     3     4           2          2       4         2    5.0
# 25    16     4     4           1          2       5         3    2.0
# 26    18     4     4           1          2       3         2    4.0
# 27    17     3     2           1          1       5         5    5.0
# 28    15     3     1           2          4       4         4    2.0
# 29    19     2     3           1          1       4         4    4.0
# ..   ...   ...   ...         ...        ...     ...       ...    ...
# 619   16     4     4           1          1       4         5    5.0
# 620   16     1     1           2          1       3         4    4.0
# 621   15     4     1           1          2       5         3    4.0
# 622   15     3     4           1          2       5         3    2.0
# 623   17     3     3           1          2       5         3    3.0
# 624   16     2     2           1          2       4         3    4.0
# 625   17     3     2           2          2       4         1    2.0
# 626   18     1     3           2          2       3         3    4.0
# 627   17     3     2           2          1       4         3    3.0
# 628   15     1     2           2          1       5         1    2.0
# 629   18     4     4           1          2       4         4    4.0
# 630   17     3     4           1          3       4         4    3.0
# 631   16     4     3           1          2       5         4    2.0
# 632   18     4     4           1          2       5         4    3.0
# 633   17     1     2           1          1       2         2    2.0
# 634   15     4     4           2          2       4         4    4.0
# 635   18     2     2           1          2       3         2    3.0
# 636   16     4     4           1          2       4         3    1.0
# 637   18     3     2           3          1       4         4    1.0
# 638   15     4     4           1          4       1         3    3.0
# 639   17     2     1           1          1       4         4    2.0
# 640   15     2     2           1          1       4         3    1.0
# 641   17     1     4           4          1       5         5    4.0
# 642   17     3     2           1          2       4         5    4.0
# 643   15     3     3           2          1       5         4    4.0
# 644   18     2     2           4          2       4         2    5.0
# 645   15     4     4           2          2       4         3    1.0
# 646   21     1     1           2          2       5         3    3.0
# 647   16     2     2           1          1       4         3    4.0
# 648   16     2     3          40          2       4         5    4.0
#
#          Dalc  Walc  health  sex_M  address_U  famsize_LE3  Pstatus_T  \
# 0    1.000000   2.0       5      1          1            0          1
# 1    1.000000   2.0       5      0          1            0          1
# 2    2.000000   4.0       5      1          0            1          1
# 3    2.000000   4.0       4      1          1            0          1
# 4    1.000000   2.0       5      0          0            0          1
# 5    1.000000   1.0       5      0          1            1          1
# 6    1.000000   2.0       2      0          0            0          1
# 7    1.000000   1.0       4      0          1            0          0
# 8    3.000000   3.0       5      1          0            0          1
# 9    1.000000   2.0       4      0          1            1          1
# 10   2.000000   4.0       5      0          1            0          1
# 11   1.000000   2.0       4      1          1            0          1
# 12   1.000000   1.0       1      0          1            1          1
# 13   1.000000   1.0       5      0          1            0          0
# 14   3.000000   5.0       5      1          1            0          1
# 15   1.000000   1.0       1      1          1            1          0
# 16   1.000000   1.0       3      1          1            0          1
# 17   1.000000   3.0       1      0          1            0          0
# 18   1.000000   1.0       1      0          1            0          1
# 19   1.000000   1.0       4      0          0            0          1
# 20   1.000000   2.0       3      0          1            1          1
# 21   1.000000   2.0       3      0          1            0          1
# 22   5.000000   5.0       1      1          1            1          1
# 23   4.000000   3.0       5      0          1            0          1
# 24   3.000000   4.0       1      1          0            1          0
# 25   1.000000   3.0       2      1          0            1          0
# 26   1.000000   4.0       2      1          1            0          1
# 27   2.000000   4.0       5      1          1            0          1
# 28   2.000000   3.0       3      0          0            1          1
# 29   1.000000   1.0       2      0          1            0          1
# ..        ...   ...     ...    ...        ...          ...        ...
# 619  5.000000   5.0       4      1          1            0          1
# 620  3.000000   4.0       5      1          0            0          1
# 621  1.000000   2.0       2      1          0            1          1
# 622  1.000000   1.0       1      0          1            1          0
# 623  2.000000   3.0       1      0          1            1          1
# 624  1.000000   2.0       2      0          1            1          1
# 625  2.000000   2.0       1      1          1            0          1
# 626  2.000000   4.0       3      1          0            0          1
# 627  2.000000   2.0       1      0          1            0          1
# 628  1.497653   1.0       1      0          0            0          1
# 629  1.497653   3.0       5      0          1            0          1
# 630  3.000000   4.0       5      0          1            0          1
# 631  1.000000   2.0       5      1          1            1          1
# 632  1.497653   4.0       2      0          0            1          1
# 633  3.000000   3.0       5      1          0            1          1
# 634  2.000000   3.0       5      0          1            0          1
# 635  1.000000   1.0       5      0          0            0          1
# 636  1.000000   1.0       3      1          1            0          1
# 637  3.000000   4.0       5      1          0            1          1
# 638  5.000000   5.0       3      1          1            0          0
# 639  2.000000   4.0       5      1          0            0          1
# 640  1.000000   1.0       2      0          0            0          1
# 641  1.000000   1.0       5      0          0            1          0
# 642  1.000000   2.0       5      0          0            0          1
# 643  2.000000   3.0       5      0          0            0          1
# 644  1.000000   1.0       2      0          1            0          1
# 645  1.000000   1.0       5      1          1            0          1
# 646  5.000000   2.0       4      1          0            1          1
# 647  1.000000   2.0       1      0          1            1          0
# 648  1.000000   2.0       1      0          0            0          1
#
#      nursery  plans_universitypast_failures  attedance
# 0          1                             10         26
# 1          1                             10         30
# 2          1                             10         32
# 3          0                            -10         22
# 4          1                             10         32
# 5          1                             10         24
# 6          1                             10         32
# 7          1                             10         22
# 8          1                             11         28
# 9          1                             10         22
# 10         1                             10         28
# 11         1                             10         31
# 12         1                             10         28
# 13         0                             10         28
# 14         0                             10         32
# 15         1                             10         28
# 16         1                             10         32
# 17         1                             11         24
# 18         1                             10         32
# 19         1                             10         27
# 20         1                             10         32
# 21         1                             10         28
# 22         0                             10         24
# 23         1                            -10         20
# 24         1                             10         26
# 25         1                             10         27
# 26         0                             10         28
# 27         1                             13         30
# 28         0                             10         26
# 29         1                            -11         32
# ..       ...                            ...        ...
# 619        1                             10         20
# 620        1                             10         26
# 621        1                             10         32
# 622        1                             10         32
# 623        1                             10          0
# 624        1                             10         26
# 625        1                             10         32
# 626        1                             10         32
# 627        1                             10         27
# 628        1                             10         29
# 629        1                             10         32
# 630        1                             11         18
# 631        1                             10         26
# 632        1                             10         31
# 633        1                             13         18
# 634        1                             10         28
# 635        1                             10         28
# 636        1                             10         32
# 637        0                             10         28
# 638        0                             10         32
# 639        0                             10         32
# 640        1                             10         24
# 641        1                             11         18
# 642        1                             11         32
# 643        1                             10         28
# 644        1                             10         30
# 645        1                             10         30
# 646        1                            -12         11
# 647        1                            -10         26
# 648        1                             10         30
#
# [649 rows x 18 columns]

# %% [markdown]
# ### Задача 4: сломанный признак
# __(0.5 балла)__
#
# Найдите в данных сломанный признак (он не соответствует описанию) и исправьте его.

# %%
#plans_universitypast_failure

# %% [markdown]
# ### Задача 5: борьба с выбросами
# __(1.5 балла)__
#
# Качество предсказания может ухудшаться, если в данных присутствуют корректные значения признаков (с точки зрения чтения данных и применения методов), но не соответствующие реальным объектам. Например, данные могли быть введены в неверном формате, а потом слишком грубо приведены к общему виду, из-за чего ошибка не была замечена.
# Попробуем от такого избавиться &mdash; а для этого такие объекты нужно сначала найти. Конечно, нам еще недоступны многие продвинутые способы, но давайте попробуем обойтись простыми.
#
# Первый способ это сделать &mdash; посмотреть для каждого признака на распределение его значений и проверить крайние значения на правдоподобность.
#
# *Hint 1: используйте функцию DataFrame.hist*
#
# *Hint 2: в описании датасета выше есть информация, необходимая для восстановления правильных значений*

# %%
data = pd.read_csv("data.csv")
a = {}
b = {}
a["age"] = 1
b["age"] = 20
a["traveltime"] = 0
b["traveltime"] = 4
a["Medu"] = 0
b["Medu"] = 5
a["studytime"] = 1
b["studytime"] = 4
a["famrel"] = 0
b["famrel"] = 4
a["freetime"] = 0
b["freetime"] = 4
a["goout"] = 0
b["goout"] = 4
for i in data.keys():
    for j in range(649):
        try:
            if data[i][j] < a[i]:
                data[i][j] = a[i]
            if data[i][j] > b[i]:
                data[i][j] = b[i]
        except:
            continue
hist = data.hist(bins=3, figsize = (10, 10))
# Out:
# /Users/elibay/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# Другой простой способ найти выбросы &mdash; сделать предсказание на всех объектах и посмотреть на объекты с наибольшей ошибкой. Обратите внимание, что просто удалять все объекты с высокой ошибкой нельзя &mdash; это, конечно, хороший способ добиться меньшей ошибки (на данной выборке), но одновременно вы ухудшите обобщающую способность алгоритма. Вместо этого вам нужно найти однозначно ошибочные записи и их исправить.
#
# *Hint: возможно, все проблемы уже были найдены в прошлом пункте; для проверки &mdash; в обоих пунктах в сумме нужно исправить 3 проблемы.*

# %%
model.fit(data, target)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
err = [abs(model.predict([data.iloc[i]])[0] - target.iloc[i]) for i in range(649)]

# %%
err
# Out:
# [Ans    6.999128
#  Name: 0, dtype: float64, Ans    20.825175
#  Name: 1, dtype: float64, Ans    2.319729
#  Name: 2, dtype: float64, Ans    15.311685
#  Name: 3, dtype: float64, Ans    0.744924
#  Name: 4, dtype: float64, Ans    14.635379
#  Name: 5, dtype: float64, Ans    11.141829
#  Name: 6, dtype: float64, Ans    16.832158
#  Name: 7, dtype: float64, Ans    6.124973
#  Name: 8, dtype: float64, Ans    13.236836
#  Name: 9, dtype: float64, Ans    5.821033
#  Name: 10, dtype: float64, Ans    8.239769
#  Name: 11, dtype: float64, Ans    5.027115
#  Name: 12, dtype: float64, Ans    10.756023
#  Name: 13, dtype: float64, Ans    29.933242
#  Name: 14, dtype: float64, Ans    1.342849
#  Name: 15, dtype: float64, Ans    33.081579
#  Name: 16, dtype: float64, Ans    22.552686
#  Name: 17, dtype: float64, Ans    5.376886
#  Name: 18, dtype: float64, Ans    13.337124
#  Name: 19, dtype: float64, Ans    15.063094
#  Name: 20, dtype: float64, Ans    10.228053
#  Name: 21, dtype: float64, Ans    0.279883
#  Name: 22, dtype: float64, Ans    18.705116
#  Name: 23, dtype: float64, Ans    20.80016
#  Name: 24, dtype: float64, Ans    10.366391
#  Name: 25, dtype: float64, Ans    28.174692
#  Name: 26, dtype: float64, Ans    20.014033
#  Name: 27, dtype: float64, Ans    9.304761
#  Name: 28, dtype: float64, Ans    0.162455
#  Name: 29, dtype: float64, Ans    3.791759
#  Name: 30, dtype: float64, Ans    0.509868
#  Name: 31, dtype: float64, Ans    8.345001
#  Name: 32, dtype: float64, Ans    1.764758
#  Name: 33, dtype: float64, Ans    23.761907
#  Name: 34, dtype: float64, Ans    1.873314
#  Name: 35, dtype: float64, Ans    17.705768
#  Name: 36, dtype: float64, Ans    3.519074
#  Name: 37, dtype: float64, Ans    10.559863
#  Name: 38, dtype: float64, Ans    13.50422
#  Name: 39, dtype: float64, Ans    2.013417
#  Name: 40, dtype: float64, Ans    5.153368
#  Name: 41, dtype: float64, Ans    3.853224
#  Name: 42, dtype: float64, Ans    17.360629
#  Name: 43, dtype: float64, Ans    6.502887
#  Name: 44, dtype: float64, Ans    1.516369
#  Name: 45, dtype: float64, Ans    18.580792
#  Name: 46, dtype: float64, Ans    11.658229
#  Name: 47, dtype: float64, Ans    20.90806
#  Name: 48, dtype: float64, Ans    1.060541
#  Name: 49, dtype: float64, Ans    2.123145
#  Name: 50, dtype: float64, Ans    6.771319
#  Name: 51, dtype: float64, Ans    0.049656
#  Name: 52, dtype: float64, Ans    20.095293
#  Name: 53, dtype: float64, Ans    0.286892
#  Name: 54, dtype: float64, Ans    1.028243
#  Name: 55, dtype: float64, Ans    0.991113
#  Name: 56, dtype: float64, Ans    5.876933
#  Name: 57, dtype: float64, Ans    4.891011
#  Name: 58, dtype: float64, Ans    13.826351
#  Name: 59, dtype: float64, Ans    6.147851
#  Name: 60, dtype: float64, Ans    15.824476
#  Name: 61, dtype: float64, Ans    15.544282
#  Name: 62, dtype: float64, Ans    3.381372
#  Name: 63, dtype: float64, Ans    0.448621
#  Name: 64, dtype: float64, Ans    7.76511
#  Name: 65, dtype: float64, Ans    4.957574
#  Name: 66, dtype: float64, Ans    8.961236
#  Name: 67, dtype: float64, Ans    10.326552
#  Name: 68, dtype: float64, Ans    12.192557
#  Name: 69, dtype: float64, Ans    21.845701
#  Name: 70, dtype: float64, Ans    19.048797
#  Name: 71, dtype: float64, Ans    12.057848
#  Name: 72, dtype: float64, Ans    24.636558
#  Name: 73, dtype: float64, Ans    9.625333
#  Name: 74, dtype: float64, Ans    1.651988
#  Name: 75, dtype: float64, Ans    7.244412
#  Name: 76, dtype: float64, Ans    10.413927
#  Name: 77, dtype: float64, Ans    18.341814
#  Name: 78, dtype: float64, Ans    13.838161
#  Name: 79, dtype: float64, Ans    26.638375
#  Name: 80, dtype: float64, Ans    12.040435
#  Name: 81, dtype: float64, Ans    12.836424
#  Name: 82, dtype: float64, Ans    6.249456
#  Name: 83, dtype: float64, Ans    6.708282
#  Name: 84, dtype: float64, Ans    10.791433
#  Name: 85, dtype: float64, Ans    21.984205
#  Name: 86, dtype: float64, Ans    2.462958
#  Name: 87, dtype: float64, Ans    5.163397
#  Name: 88, dtype: float64, Ans    2.044091
#  Name: 89, dtype: float64, Ans    9.587576
#  Name: 90, dtype: float64, Ans    11.26867
#  Name: 91, dtype: float64, Ans    4.034259
#  Name: 92, dtype: float64, Ans    22.494597
#  Name: 93, dtype: float64, Ans    6.012778
#  Name: 94, dtype: float64, Ans    18.448081
#  Name: 95, dtype: float64, Ans    7.093924
#  Name: 96, dtype: float64, Ans    3.464546
#  Name: 97, dtype: float64, Ans    24.383138
#  Name: 98, dtype: float64, Ans    5.056218
#  Name: 99, dtype: float64, Ans    11.859061
#  Name: 100, dtype: float64, Ans    6.861472
#  Name: 101, dtype: float64, Ans    14.164187
#  Name: 102, dtype: float64, Ans    1.597625
#  Name: 103, dtype: float64, Ans    1.634219
#  Name: 104, dtype: float64, Ans    19.213707
#  Name: 105, dtype: float64, Ans    18.849727
#  Name: 106, dtype: float64, Ans    4.681956
#  Name: 107, dtype: float64, Ans    12.740064
#  Name: 108, dtype: float64, Ans    17.373632
#  Name: 109, dtype: float64, Ans    10.925902
#  Name: 110, dtype: float64, Ans    2.347888
#  Name: 111, dtype: float64, Ans    5.871196
#  Name: 112, dtype: float64, Ans    15.520193
#  Name: 113, dtype: float64, Ans    2.270494
#  Name: 114, dtype: float64, Ans    3.77918
#  Name: 115, dtype: float64, Ans    2.691301
#  Name: 116, dtype: float64, Ans    22.154604
#  Name: 117, dtype: float64, Ans    30.066863
#  Name: 118, dtype: float64, Ans    2.334304
#  Name: 119, dtype: float64, Ans    7.551588
#  Name: 120, dtype: float64, Ans    2.767642
#  Name: 121, dtype: float64, Ans    9.944689
#  Name: 122, dtype: float64, Ans    0.757693
#  Name: 123, dtype: float64, Ans    18.350804
#  Name: 124, dtype: float64, Ans    7.388451
#  Name: 125, dtype: float64, Ans    3.084676
#  Name: 126, dtype: float64, Ans    7.750505
#  Name: 127, dtype: float64, Ans    5.866966
#  Name: 128, dtype: float64, Ans    5.643813
#  Name: 129, dtype: float64, Ans    3.14056
#  Name: 130, dtype: float64, Ans    16.949583
#  Name: 131, dtype: float64, Ans    3.972926
#  Name: 132, dtype: float64, Ans    14.783188
#  Name: 133, dtype: float64, Ans    18.01927
#  Name: 134, dtype: float64, Ans    7.666987
#  Name: 135, dtype: float64, Ans    19.340285
#  Name: 136, dtype: float64, Ans    43.609927
#  Name: 137, dtype: float64, Ans    1.511136
#  Name: 138, dtype: float64, Ans    10.58557
#  Name: 139, dtype: float64, Ans    16.889849
#  Name: 140, dtype: float64, Ans    21.623498
#  Name: 141, dtype: float64, Ans    5.084898
#  Name: 142, dtype: float64, Ans    14.442045
#  Name: 143, dtype: float64, Ans    0.620594
#  Name: 144, dtype: float64, Ans    17.48447
#  Name: 145, dtype: float64, Ans    6.740199
#  Name: 146, dtype: float64, Ans    15.589574
#  Name: 147, dtype: float64, Ans    8.022842
#  Name: 148, dtype: float64, Ans    14.524892
#  Name: 149, dtype: float64, Ans    8.364081
#  Name: 150, dtype: float64, Ans    6.970707
#  Name: 151, dtype: float64, Ans    16.194729
#  Name: 152, dtype: float64, Ans    17.636867
#  Name: 153, dtype: float64, Ans    9.000535
#  Name: 154, dtype: float64, Ans    3.460246
#  Name: 155, dtype: float64, Ans    3.545593
#  Name: 156, dtype: float64, Ans    0.149403
#  Name: 157, dtype: float64, Ans    23.10527
#  Name: 158, dtype: float64, Ans    12.290967
#  Name: 159, dtype: float64, Ans    5.815142
#  Name: 160, dtype: float64, Ans    12.683764
#  Name: 161, dtype: float64, Ans    0.226007
#  Name: 162, dtype: float64, Ans    10.370302
#  Name: 163, dtype: float64, Ans    3.60619
#  Name: 164, dtype: float64, Ans    26.289037
#  Name: 165, dtype: float64, Ans    7.07859
#  Name: 166, dtype: float64, Ans    2.875038
#  Name: 167, dtype: float64, Ans    2.769705
#  Name: 168, dtype: float64, Ans    0.438884
#  Name: 169, dtype: float64, Ans    9.817091
#  Name: 170, dtype: float64, Ans    1.969318
#  Name: 171, dtype: float64, Ans    18.290882
#  Name: 172, dtype: float64, Ans    23.815082
#  Name: 173, dtype: float64, Ans    22.801103
#  Name: 174, dtype: float64, Ans    7.573776
#  Name: 175, dtype: float64, Ans    9.359405
#  Name: 176, dtype: float64, Ans    4.02434
#  Name: 177, dtype: float64, Ans    13.259049
#  Name: 178, dtype: float64, Ans    10.864834
#  Name: 179, dtype: float64, Ans    7.119271
#  Name: 180, dtype: float64, Ans    4.061908
#  Name: 181, dtype: float64, Ans    10.992054
#  Name: 182, dtype: float64, Ans    8.209771
#  Name: 183, dtype: float64, Ans    7.846297
#  Name: 184, dtype: float64, Ans    9.905128
#  Name: 185, dtype: float64, Ans    2.388912
#  Name: 186, dtype: float64, Ans    4.607293
#  Name: 187, dtype: float64, Ans    30.146245
#  Name: 188, dtype: float64, Ans    3.922555
#  Name: 189, dtype: float64, Ans    10.23356
#  Name: 190, dtype: float64, Ans    18.32231
#  Name: 191, dtype: float64, Ans    4.968656
#  Name: 192, dtype: float64, Ans    0.698022
#  Name: 193, dtype: float64, Ans    2.133415
#  Name: 194, dtype: float64, Ans    11.853841
#  Name: 195, dtype: float64, Ans    37.024438
#  Name: 196, dtype: float64, Ans    0.969106
#  Name: 197, dtype: float64, Ans    22.136468
#  Name: 198, dtype: float64, Ans    9.573306
#  Name: 199, dtype: float64, Ans    20.531766
#  Name: 200, dtype: float64, Ans    4.034902
#  Name: 201, dtype: float64, Ans    5.876515
#  Name: 202, dtype: float64, Ans    2.172235
#  Name: 203, dtype: float64, Ans    8.046615
#  Name: 204, dtype: float64, Ans    18.354987
#  Name: 205, dtype: float64, Ans    15.40303
#  Name: 206, dtype: float64, Ans    0.305939
#  Name: 207, dtype: float64, Ans    18.461307
#  Name: 208, dtype: float64, Ans    2.802558
#  Name: 209, dtype: float64, Ans    5.077063
#  Name: 210, dtype: float64, Ans    7.532524
#  Name: 211, dtype: float64, Ans    2.970106
#  Name: 212, dtype: float64, Ans    4.961976
#  Name: 213, dtype: float64, Ans    13.242075
#  Name: 214, dtype: float64, Ans    20.065577
#  Name: 215, dtype: float64, Ans    12.560694
#  Name: 216, dtype: float64, Ans    1.726486
#  Name: 217, dtype: float64, Ans    1.980179
#  Name: 218, dtype: float64, Ans    7.973719
#  Name: 219, dtype: float64, Ans    10.067011
#  Name: 220, dtype: float64, Ans    8.486732
#  Name: 221, dtype: float64, Ans    7.800995
#  Name: 222, dtype: float64, Ans    5.769372
#  Name: 223, dtype: float64, Ans    10.922731
#  Name: 224, dtype: float64, Ans    15.981936
#  Name: 225, dtype: float64, Ans    11.169738
#  Name: 226, dtype: float64, Ans    4.088511
#  Name: 227, dtype: float64, Ans    4.992806
#  Name: 228, dtype: float64, Ans    5.877716
#  Name: 229, dtype: float64, Ans    1.848289
#  Name: 230, dtype: float64, Ans    59.855804
#  Name: 231, dtype: float64, Ans    6.19879
#  Name: 232, dtype: float64, Ans    15.114217
#  Name: 233, dtype: float64, Ans    0.947753
#  Name: 234, dtype: float64, Ans    10.083927
#  Name: 235, dtype: float64, Ans    17.793989
#  Name: 236, dtype: float64, Ans    12.603205
#  Name: 237, dtype: float64, Ans    9.08715
#  Name: 238, dtype: float64, Ans    5.415391
#  Name: 239, dtype: float64, Ans    14.477728
#  Name: 240, dtype: float64, Ans    8.48125
#  Name: 241, dtype: float64, Ans    11.284766
#  Name: 242, dtype: float64, Ans    9.203051
#  Name: 243, dtype: float64, Ans    12.981941
#  Name: 244, dtype: float64, Ans    6.328444
#  Name: 245, dtype: float64, Ans    5.068456
#  Name: 246, dtype: float64, Ans    13.808108
#  Name: 247, dtype: float64, Ans    12.799463
#  Name: 248, dtype: float64, Ans    9.656232
#  Name: 249, dtype: float64, Ans    21.432056
#  Name: 250, dtype: float64, Ans    14.449615
#  Name: 251, dtype: float64, Ans    0.236329
#  Name: 252, dtype: float64, Ans    1.878054
#  Name: 253, dtype: float64, Ans    15.274175
#  Name: 254, dtype: float64, Ans    12.546413
#  Name: 255, dtype: float64, Ans    10.709489
#  Name: 256, dtype: float64, Ans    63.294489
#  Name: 257, dtype: float64, Ans    6.153813
#  Name: 258, dtype: float64, Ans    11.850858
#  Name: 259, dtype: float64, Ans    3.074908
#  Name: 260, dtype: float64, Ans    13.634858
#  Name: 261, dtype: float64, Ans    32.366872
#  Name: 262, dtype: float64, Ans    13.092052
#  Name: 263, dtype: float64, Ans    4.294951
#  Name: 264, dtype: float64, Ans    26.040418
#  Name: 265, dtype: float64, Ans    5.477897
#  Name: 266, dtype: float64, Ans    3.8483
#  Name: 267, dtype: float64, Ans    1.031363
#  Name: 268, dtype: float64, Ans    6.761951
#  Name: 269, dtype: float64, Ans    0.884234
#  Name: 270, dtype: float64, Ans    13.034446
#  Name: 271, dtype: float64, Ans    13.325909
#  Name: 272, dtype: float64, Ans    0.080472
#  Name: 273, dtype: float64, Ans    11.782899
#  Name: 274, dtype: float64, Ans    10.292268
#  Name: 275, dtype: float64, Ans    21.12732
#  Name: 276, dtype: float64, Ans    20.730679
#  Name: 277, dtype: float64, Ans    23.263737
#  Name: 278, dtype: float64, Ans    2.971971
#  Name: 279, dtype: float64, Ans    1.674443
#  Name: 280, dtype: float64, Ans    4.991504
#  Name: 281, dtype: float64, Ans    3.38907
#  Name: 282, dtype: float64, Ans    1.704253
#  Name: 283, dtype: float64, Ans    22.469164
#  Name: 284, dtype: float64, Ans    15.639952
#  Name: 285, dtype: float64, Ans    14.098296
#  Name: 286, dtype: float64, Ans    43.735604
#  Name: 287, dtype: float64, Ans    8.144094
#  Name: 288, dtype: float64, Ans    3.524579
#  Name: 289, dtype: float64, Ans    11.105135
#  Name: 290, dtype: float64, Ans    4.06123
#  Name: 291, dtype: float64, Ans    20.580277
#  Name: 292, dtype: float64, Ans    11.81775
#  Name: 293, dtype: float64, Ans    18.459522
#  Name: 294, dtype: float64, Ans    9.190431
#  Name: 295, dtype: float64, Ans    11.509392
#  Name: 296, dtype: float64, Ans    6.379471
#  Name: 297, dtype: float64, Ans    17.65174
#  Name: 298, dtype: float64, Ans    18.170778
#  Name: 299, dtype: float64, Ans    32.645396
#  Name: 300, dtype: float64, Ans    11.10755
#  Name: 301, dtype: float64, Ans    1.125168
#  Name: 302, dtype: float64, Ans    51.100379
#  Name: 303, dtype: float64, Ans    10.83598
#  Name: 304, dtype: float64, Ans    8.829644
#  Name: 305, dtype: float64, Ans    1.96615
#  Name: 306, dtype: float64, Ans    2.375718
#  Name: 307, dtype: float64, Ans    18.763274
#  Name: 308, dtype: float64, Ans    3.049373
#  Name: 309, dtype: float64, Ans    15.767911
#  Name: 310, dtype: float64, Ans    18.842826
#  Name: 311, dtype: float64, Ans    4.30054
#  Name: 312, dtype: float64, Ans    2.935444
#  Name: 313, dtype: float64, Ans    4.306794
#  Name: 314, dtype: float64, Ans    12.467472
#  Name: 315, dtype: float64, Ans    3.818925
#  Name: 316, dtype: float64, Ans    23.475527
#  Name: 317, dtype: float64, Ans    11.870071
#  Name: 318, dtype: float64, Ans    62.400123
#  Name: 319, dtype: float64, Ans    3.99933
#  Name: 320, dtype: float64, Ans    40.609778
#  Name: 321, dtype: float64, Ans    5.849864
#  Name: 322, dtype: float64, Ans    7.561283
#  Name: 323, dtype: float64, Ans    3.284323
#  Name: 324, dtype: float64, Ans    7.646086
#  Name: 325, dtype: float64, Ans    18.653825
#  Name: 326, dtype: float64, Ans    2.214495
#  Name: 327, dtype: float64, Ans    0.708488
#  Name: 328, dtype: float64, Ans    6.691664
#  Name: 329, dtype: float64, Ans    1.771537
#  Name: 330, dtype: float64, Ans    7.157154
#  Name: 331, dtype: float64, Ans    2.003748
#  Name: 332, dtype: float64, Ans    20.400892
#  Name: 333, dtype: float64, Ans    18.516527
#  Name: 334, dtype: float64, Ans    10.655577
#  Name: 335, dtype: float64, Ans    7.336945
#  Name: 336, dtype: float64, Ans    1.116738
#  Name: 337, dtype: float64, Ans    13.436538
#  Name: 338, dtype: float64, Ans    3.326595
#  Name: 339, dtype: float64, Ans    11.257673
#  Name: 340, dtype: float64, Ans    23.905561
#  Name: 341, dtype: float64, Ans    6.339436
#  Name: 342, dtype: float64, Ans    8.968364
#  Name: 343, dtype: float64, Ans    1.159566
#  Name: 344, dtype: float64, Ans    4.819582
#  Name: 345, dtype: float64, Ans    14.976128
#  Name: 346, dtype: float64, Ans    23.078914
#  Name: 347, dtype: float64, Ans    3.844636
#  Name: 348, dtype: float64, Ans    23.21717
#  Name: 349, dtype: float64, Ans    4.481307
#  Name: 350, dtype: float64, Ans    10.745416
#  Name: 351, dtype: float64, Ans    12.29442
#  Name: 352, dtype: float64, Ans    4.604625
#  Name: 353, dtype: float64, Ans    63.867592
#  Name: 354, dtype: float64, Ans    2.321154
#  Name: 355, dtype: float64, Ans    0.48785
#  Name: 356, dtype: float64, Ans    14.342465
#  Name: 357, dtype: float64, Ans    11.719452
#  Name: 358, dtype: float64, Ans    23.898704
#  Name: 359, dtype: float64, Ans    5.144217
#  Name: 360, dtype: float64, Ans    7.437042
#  Name: 361, dtype: float64, Ans    0.52108
#  Name: 362, dtype: float64, Ans    13.328316
#  Name: 363, dtype: float64, Ans    6.035905
#  Name: 364, dtype: float64, Ans    9.277898
#  Name: 365, dtype: float64, Ans    39.152351
#  Name: 366, dtype: float64, Ans    2.643739
#  Name: 367, dtype: float64, Ans    0.509812
#  Name: 368, dtype: float64, Ans    12.39965
#  Name: 369, dtype: float64, Ans    3.506359
#  Name: 370, dtype: float64, Ans    14.115603
#  Name: 371, dtype: float64, Ans    5.182218
#  Name: 372, dtype: float64, Ans    16.744089
#  Name: 373, dtype: float64, Ans    5.718849
#  Name: 374, dtype: float64, Ans    11.806799
#  Name: 375, dtype: float64, Ans    15.796587
#  Name: 376, dtype: float64, Ans    12.648765
#  Name: 377, dtype: float64, Ans    3.267343
#  Name: 378, dtype: float64, Ans    7.429437
#  Name: 379, dtype: float64, Ans    0.224864
#  Name: 380, dtype: float64, Ans    1.762699
#  Name: 381, dtype: float64, Ans    0.067609
#  Name: 382, dtype: float64, Ans    5.457548
#  Name: 383, dtype: float64, Ans    11.285317
#  Name: 384, dtype: float64, Ans    59.426557
#  Name: 385, dtype: float64, Ans    4.028236
#  Name: 386, dtype: float64, Ans    15.219848
#  Name: 387, dtype: float64, Ans    0.478794
#  Name: 388, dtype: float64, Ans    1.556395
#  Name: 389, dtype: float64, Ans    13.500028
#  Name: 390, dtype: float64, Ans    7.998495
#  Name: 391, dtype: float64, Ans    11.076444
#  Name: 392, dtype: float64, Ans    3.924002
#  Name: 393, dtype: float64, Ans    6.564195
#  Name: 394, dtype: float64, Ans    14.371217
#  Name: 395, dtype: float64, Ans    16.458331
#  Name: 396, dtype: float64, Ans    1.412011
#  Name: 397, dtype: float64, Ans    4.941509
#  Name: 398, dtype: float64, Ans    1.859536
#  Name: 399, dtype: float64, Ans    7.156071
#  Name: 400, dtype: float64, Ans    7.6669
#  Name: 401, dtype: float64, Ans    4.793152
#  Name: 402, dtype: float64, Ans    16.043757
#  Name: 403, dtype: float64, Ans    59.954963
#  Name: 404, dtype: float64, Ans    7.331827
#  Name: 405, dtype: float64, Ans    19.039196
#  Name: 406, dtype: float64, Ans    1.065349
#  Name: 407, dtype: float64, Ans    10.965973
#  Name: 408, dtype: float64, Ans    5.923161
#  Name: 409, dtype: float64, Ans    4.521949
#  Name: 410, dtype: float64, Ans    17.56922
#  Name: 411, dtype: float64, Ans    7.648692
#  Name: 412, dtype: float64, Ans    3.624618
#  Name: 413, dtype: float64, Ans    8.958367
#  Name: 414, dtype: float64, Ans    2.704586
#  Name: 415, dtype: float64, Ans    22.968536
#  Name: 416, dtype: float64, Ans    0.794118
#  Name: 417, dtype: float64, Ans    7.593117
#  Name: 418, dtype: float64, Ans    3.121544
#  Name: 419, dtype: float64, Ans    2.379774
#  Name: 420, dtype: float64, Ans    1.618954
#  Name: 421, dtype: float64, Ans    6.018836
#  Name: 422, dtype: float64, Ans    51.080829
#  Name: 423, dtype: float64, Ans    11.789579
#  Name: 424, dtype: float64, Ans    1.050061
#  Name: 425, dtype: float64, Ans    0.226307
#  Name: 426, dtype: float64, Ans    8.239383
#  Name: 427, dtype: float64, Ans    13.028636
#  Name: 428, dtype: float64, Ans    7.630712
#  Name: 429, dtype: float64, Ans    24.870182
#  Name: 430, dtype: float64, Ans    1.876691
#  Name: 431, dtype: float64, Ans    7.74074
#  Name: 432, dtype: float64, Ans    0.106431
#  Name: 433, dtype: float64, Ans    6.252381
#  Name: 434, dtype: float64, Ans    8.447088
#  Name: 435, dtype: float64, Ans    48.358574
#  Name: 436, dtype: float64, Ans    3.907208
#  Name: 437, dtype: float64, Ans    31.465652
#  Name: 438, dtype: float64, Ans    5.030034
#  Name: 439, dtype: float64, Ans    18.197863
#  Name: 440, dtype: float64, Ans    9.093182
#  Name: 441, dtype: float64, Ans    2.757135
#  Name: 442, dtype: float64, Ans    11.721736
#  Name: 443, dtype: float64, Ans    15.096298
#  Name: 444, dtype: float64, Ans    0.287551
#  Name: 445, dtype: float64, Ans    2.100475
#  Name: 446, dtype: float64, Ans    5.801457
#  Name: 447, dtype: float64, Ans    9.560309
#  Name: 448, dtype: float64, Ans    2.07768
#  Name: 449, dtype: float64, Ans    0.518668
#  Name: 450, dtype: float64, Ans    10.682464
#  Name: 451, dtype: float64, Ans    10.553911
#  Name: 452, dtype: float64, Ans    0.068242
#  Name: 453, dtype: float64, Ans    13.269313
#  Name: 454, dtype: float64, Ans    4.371072
#  Name: 455, dtype: float64, Ans    4.461353
#  Name: 456, dtype: float64, Ans    3.909345
#  Name: 457, dtype: float64, Ans    7.757651
#  Name: 458, dtype: float64, Ans    6.386266
#  Name: 459, dtype: float64, Ans    7.452174
#  Name: 460, dtype: float64, Ans    2.51475
#  Name: 461, dtype: float64, Ans    58.673766
#  Name: 462, dtype: float64, Ans    8.328626
#  Name: 463, dtype: float64, Ans    2.661051
#  Name: 464, dtype: float64, Ans    8.127678
#  Name: 465, dtype: float64, Ans    14.253088
#  Name: 466, dtype: float64, Ans    5.157012
#  Name: 467, dtype: float64, Ans    1.735399
#  Name: 468, dtype: float64, Ans    0.533088
#  Name: 469, dtype: float64, Ans    3.742688
#  Name: 470, dtype: float64, Ans    7.204216
#  Name: 471, dtype: float64, Ans    0.663168
#  Name: 472, dtype: float64, Ans    21.069043
#  Name: 473, dtype: float64, Ans    1.860212
#  Name: 474, dtype: float64, Ans    9.971468
#  Name: 475, dtype: float64, Ans    18.604563
#  Name: 476, dtype: float64, Ans    6.573774
#  Name: 477, dtype: float64, Ans    18.079799
#  Name: 478, dtype: float64, Ans    3.813708
#  Name: 479, dtype: float64, Ans    17.33708
#  Name: 480, dtype: float64, Ans    30.28523
#  Name: 481, dtype: float64, Ans    5.205092
#  Name: 482, dtype: float64, Ans    7.643255
#  Name: 483, dtype: float64, Ans    18.501369
#  Name: 484, dtype: float64, Ans    0.411269
#  Name: 485, dtype: float64, Ans    8.997808
#  Name: 486, dtype: float64, Ans    5.530365
#  Name: 487, dtype: float64, Ans    12.929392
#  Name: 488, dtype: float64, Ans    11.654994
#  Name: 489, dtype: float64, Ans    1.241156
#  Name: 490, dtype: float64, Ans    5.784632
#  Name: 491, dtype: float64, Ans    52.376122
#  Name: 492, dtype: float64, Ans    2.504092
#  Name: 493, dtype: float64, Ans    28.216914
#  Name: 494, dtype: float64, Ans    11.251328
#  Name: 495, dtype: float64, Ans    3.365355
#  Name: 496, dtype: float64, Ans    5.64785
#  Name: 497, dtype: float64, Ans    1.041989
#  Name: 498, dtype: float64, Ans    7.230137
#  Name: 499, dtype: float64, Ans    6.768185
#  Name: 500, dtype: float64, Ans    49.916982
#  Name: 501, dtype: float64, Ans    11.891238
#  Name: 502, dtype: float64, Ans    0.99951
#  Name: 503, dtype: float64, Ans    3.760361
#  Name: 504, dtype: float64, Ans    8.319382
#  Name: 505, dtype: float64, Ans    15.205011
#  Name: 506, dtype: float64, Ans    11.550442
#  Name: 507, dtype: float64, Ans    25.371647
#  Name: 508, dtype: float64, Ans    2.804444
#  Name: 509, dtype: float64, Ans    3.204941
#  Name: 510, dtype: float64, Ans    1.360367
#  Name: 511, dtype: float64, Ans    9.083908
#  Name: 512, dtype: float64, Ans    19.794031
#  Name: 513, dtype: float64, Ans    10.949228
#  Name: 514, dtype: float64, Ans    15.917629
#  Name: 515, dtype: float64, Ans    39.820541
#  Name: 516, dtype: float64, Ans    0.748588
#  Name: 517, dtype: float64, Ans    3.573668
#  Name: 518, dtype: float64, Ans    5.369695
#  Name: 519, dtype: float64, Ans    19.492389
#  Name: 520, dtype: float64, Ans    4.579627
#  Name: 521, dtype: float64, Ans    13.751139
#  Name: 522, dtype: float64, Ans    4.802509
#  Name: 523, dtype: float64, Ans    14.271186
#  Name: 524, dtype: float64, Ans    11.167967
#  Name: 525, dtype: float64, Ans    2.3174
#  Name: 526, dtype: float64, Ans    6.246643
#  Name: 527, dtype: float64, Ans    6.020939
#  Name: 528, dtype: float64, Ans    4.41874
#  Name: 529, dtype: float64, Ans    6.697039
#  Name: 530, dtype: float64, Ans    0.007855
#  Name: 531, dtype: float64, Ans    9.832328
#  Name: 532, dtype: float64, Ans    1.651765
#  Name: 533, dtype: float64, Ans    27.267547
#  Name: 534, dtype: float64, Ans    27.189043
#  Name: 535, dtype: float64, Ans    1.291967
#  Name: 536, dtype: float64, Ans    5.294071
#  Name: 537, dtype: float64, Ans    11.088039
#  Name: 538, dtype: float64, Ans    13.293727
#  Name: 539, dtype: float64, Ans    22.118797
#  Name: 540, dtype: float64, Ans    18.761957
#  Name: 541, dtype: float64, Ans    9.650719
#  Name: 542, dtype: float64, Ans    6.871
#  Name: 543, dtype: float64, Ans    36.660128
#  Name: 544, dtype: float64, Ans    2.691216
#  Name: 545, dtype: float64, Ans    2.857547
#  Name: 546, dtype: float64, Ans    20.018618
#  Name: 547, dtype: float64, Ans    15.275125
#  Name: 548, dtype: float64, Ans    0.182692
#  Name: 549, dtype: float64, Ans    13.519528
#  Name: 550, dtype: float64, Ans    4.832191
#  Name: 551, dtype: float64, Ans    15.098337
#  Name: 552, dtype: float64, Ans    0.968228
#  Name: 553, dtype: float64, Ans    2.990011
#  Name: 554, dtype: float64, Ans    6.888578
#  Name: 555, dtype: float64, Ans    8.221638
#  Name: 556, dtype: float64, Ans    52.513345
#  Name: 557, dtype: float64, Ans    3.787355
#  Name: 558, dtype: float64, Ans    0.219225
#  Name: 559, dtype: float64, Ans    1.352256
#  Name: 560, dtype: float64, Ans    2.894365
#  Name: 561, dtype: float64, Ans    7.747192
#  Name: 562, dtype: float64, Ans    16.050715
#  Name: 563, dtype: float64, Ans    0.601819
#  Name: 564, dtype: float64, Ans    1.495446
#  Name: 565, dtype: float64, Ans    7.729229
#  Name: 566, dtype: float64, Ans    22.563325
#  Name: 567, dtype: float64, Ans    13.92968
#  Name: 568, dtype: float64, Ans    7.448538
#  Name: 569, dtype: float64, Ans    15.558188
#  Name: 570, dtype: float64, Ans    14.045618
#  Name: 571, dtype: float64, Ans    9.125129
#  Name: 572, dtype: float64, Ans    4.789332
#  Name: 573, dtype: float64, Ans    18.375763
#  Name: 574, dtype: float64, Ans    9.272462
#  Name: 575, dtype: float64, Ans    8.971938
#  Name: 576, dtype: float64, Ans    6.42903
#  Name: 577, dtype: float64, Ans    21.297218
#  Name: 578, dtype: float64, Ans    2.343663
#  Name: 579, dtype: float64, Ans    8.068953
#  Name: 580, dtype: float64, Ans    4.827279
#  Name: 581, dtype: float64, Ans    22.120777
#  Name: 582, dtype: float64, Ans    18.978757
#  Name: 583, dtype: float64, Ans    0.539651
#  Name: 584, dtype: float64, Ans    63.519263
#  Name: 585, dtype: float64, Ans    1.299947
#  Name: 586, dtype: float64, Ans    12.379792
#  Name: 587, dtype: float64, Ans    16.007467
#  Name: 588, dtype: float64, Ans    12.172813
#  Name: 589, dtype: float64, Ans    2.722144
#  Name: 590, dtype: float64, Ans    1.193223
#  Name: 591, dtype: float64, Ans    23.606615
#  Name: 592, dtype: float64, Ans    14.741603
#  Name: 593, dtype: float64, Ans    11.1221
#  Name: 594, dtype: float64, Ans    14.13455
#  Name: 595, dtype: float64, Ans    20.102416
#  Name: 596, dtype: float64, Ans    17.024002
#  Name: 597, dtype: float64, Ans    0.292225
#  Name: 598, dtype: float64, Ans    16.009873
#  Name: 599, dtype: float64, Ans    5.312047
#  Name: 600, dtype: float64, Ans    19.57979
#  Name: 601, dtype: float64, Ans    0.635191
#  Name: 602, dtype: float64, Ans    17.164056
#  Name: 603, dtype: float64, Ans    0.861253
#  Name: 604, dtype: float64, Ans    3.434819
#  Name: 605, dtype: float64, Ans    9.966253
#  Name: 606, dtype: float64, Ans    10.509195
#  Name: 607, dtype: float64, Ans    2.420374
#  Name: 608, dtype: float64, Ans    3.678674
#  Name: 609, dtype: float64, Ans    26.689749
#  Name: 610, dtype: float64, Ans    2.741512
#  Name: 611, dtype: float64, Ans    10.590557
#  Name: 612, dtype: float64, Ans    10.561621
#  Name: 613, dtype: float64, Ans    18.20629
#  Name: 614, dtype: float64, Ans    58.88286
#  Name: 615, dtype: float64, Ans    11.983036
#  Name: 616, dtype: float64, Ans    9.096278
#  Name: 617, dtype: float64, Ans    7.229254
#  Name: 618, dtype: float64, Ans    9.957989
#  Name: 619, dtype: float64, Ans    13.428469
#  Name: 620, dtype: float64, Ans    6.678361
#  Name: 621, dtype: float64, Ans    16.91504
#  Name: 622, dtype: float64, Ans    5.803014
#  Name: 623, dtype: float64, Ans    10.143473
#  Name: 624, dtype: float64, Ans    0.519221
#  Name: 625, dtype: float64, Ans    7.418191
#  Name: 626, dtype: float64, Ans    5.932166
#  Name: 627, dtype: float64, Ans    6.455934
#  Name: 628, dtype: float64, Ans    0.911156
#  Name: 629, dtype: float64, Ans    20.796976
#  Name: 630, dtype: float64, Ans    0.711258
#  Name: 631, dtype: float64, Ans    2.533308
#  Name: 632, dtype: float64, Ans    2.457255
#  Name: 633, dtype: float64, Ans    2.605244
#  Name: 634, dtype: float64, Ans    9.033723
#  Name: 635, dtype: float64, Ans    2.125337
#  Name: 636, dtype: float64, Ans    1.440681
#  Name: 637, dtype: float64, Ans    0.106249
#  Name: 638, dtype: float64, Ans    15.546214
#  Name: 639, dtype: float64, Ans    3.380464
#  Name: 640, dtype: float64, Ans    13.940843
#  Name: 641, dtype: float64, Ans    6.743049
#  Name: 642, dtype: float64, Ans    0.687158
#  Name: 643, dtype: float64, Ans    13.76249
#  Name: 644, dtype: float64, Ans    10.008829
#  Name: 645, dtype: float64, Ans    15.562799
#  Name: 646, dtype: float64, Ans    11.382746
#  Name: 647, dtype: float64, Ans    10.690234
#  Name: 648, dtype: float64]

# %% [markdown]
# ### Финальное предсказание
#
# Проведите предсказание еще раз и сравните результат с исходным.

# %%
# Your code here
# ...
data = data.drop(columns=["plans_universitypast_failures", "traveltime"])
model2 = LinearRegression()
cross_val_score(model2, data, target).mean()
# Out:
# 0.09064036104525146
